# %%
# Import necessary libraries
import pandas as pd
import os
from data_loader import read_and_flatten_data, preprocess_text

# %%
# Define the path components
directory = "sample-data"
kaggle_filename = "kaggle_histories_titles.csv"
ipod_filename = "IPOD_titles.csv"
kaggle_file_path = os.path.join("..", directory, kaggle_filename)
ipod_file_path = os.path.join("..", directory, ipod_filename)

# %%
os.getcwd()
kaggle_file_path
# Out:
# '..\\sample-data\\kaggle_histories_titles.csv'

# %%
# Load and preprocess the data from titles.csv
titles = read_and_flatten_data(kaggle_file_path)
preprocessed_titles = preprocess_text(titles)

# Load data from IPOD_titles.csv
ipod_data = pd.read_csv(ipod_file_path)
ipod_titles = ipod_data['Original_Title'].tolist()
preprocessed_ipod_titles = preprocess_text(ipod_titles)

# Combine both lists of titles
combined_titles = preprocessed_titles + preprocessed_ipod_titles

# Convert to DataFrame
df = pd.DataFrame(combined_titles, columns=['title'])

# %%
# Display the first few rows of the DataFrame
df.count()
# Out:
# title    597372
# dtype: int64

# %%
# Number of distinct job titles
distinct_titles = df['title'].nunique()
distinct_titles
# Out:
# 311023

# %%
top_titles = df['title'].value_counts().head(25)
print(top_titles)
# Out:
# title
# director                        3620
# project manager                 3127
# intern                          2959
# manager                         2582
# managing director               2258
# software engineer               2204
# general manager                 2047
# consultant                      2023
# assistant manager               1773
# sales manager                   1578
# business development manager    1557
# account manager                 1520
# associate                       1498
# project engineer                1462
# finance manager                 1435
# ceo                             1353
# accountant                      1323
# vice president                  1301
# owner                           1289
# senior manager                  1214
# senior software engineer        1214
# account executive               1167
# engineer                        1106
# operations manager              1063
# senior consultant               1046
# Name: count, dtype: int64

# %%
# Frequency of each job title
title_counts = df['title'].value_counts()
title_counts
# Out:
# title
# director                                               3620
# project manager                                        3127
# intern                                                 2959
# manager                                                2582
# managing director                                      2258
#                                                        ...
# site material supply manager                              1
# cto of company                                            1
# procurment engineering                                    1
# svice president & chief government strategy officer       1
# chief food fighter and co-founder                         1
# Name: count, Length: 311023, dtype: int64

# %%
# Percentage of total job titles covered by different frequencies of distinct job titles
frequency_breakdown = title_counts.value_counts(normalize=True).sort_index()
frequency_breakdown
# Out:
# count
# 1       0.880906
# 2       0.063462
# 3       0.018037
# 4       0.009115
# 5       0.005244
#           ...
# 2258    0.000003
# 2582    0.000003
# 2959    0.000003
# 3127    0.000003
# 3620    0.000003
# Name: proportion, Length: 329, dtype: float64

# %%
# Breakdown percentage of total job titles covered by unique (freq = 1) titles
unique_title_count = title_counts[title_counts == 1].sum()
total_titles = df.shape[0]
percentage_unique_titles = (unique_title_count / total_titles) * 100

# Percentage of total job title occurrences covered by non-unique titles
non_unique_titles_count = total_titles - unique_title_count
percentage_non_unique_occurrences = (non_unique_titles_count / total_titles) * 100

# Calculate percentage coverage by the most frequent distinct titles
def percentage_coverage_by_top_titles(percent):
    top_n_count = int(len(title_counts) * (percent / 100))
    top_n_titles = title_counts.head(top_n_count)
    coverage = (top_n_titles.sum() / total_titles) * 100
    return coverage

coverage_top_5 = percentage_coverage_by_top_titles(5)
coverage_top_10 = percentage_coverage_by_top_titles(10)
coverage_top_20 = percentage_coverage_by_top_titles(20)
coverage_top_50 = percentage_coverage_by_top_titles(50)

# Display results
print(f"Percentage of total job titles covered by unique (freq = 1) titles: {percentage_unique_titles:.2f}%")
print(f"Percentage of total job title occurrences covered by non-unique titles: {percentage_non_unique_occurrences:.2f}%")
print(f"Top 5% most frequent distinct titles cover {coverage_top_5:.2f}% of title occurrences")
print(f"Top 10% most frequent distinct titles cover {coverage_top_10:.2f}% of title occurrences")
print(f"Top 20% most frequent distinct titles cover {coverage_top_20:.2f}% of title occurrences")
print(f"Top 50% most frequent distinct titles cover {coverage_top_50:.2f}% of title occurrences")
# Out:
# Percentage of total job titles covered by unique (freq = 1) titles: 45.86%
# Percentage of total job title occurrences covered by non-unique titles: 54.14%
# Top 5% most frequent distinct titles cover 46.65% of title occurrences
# Top 10% most frequent distinct titles cover 52.15% of title occurrences
# Top 20% most frequent distinct titles cover 58.35% of title occurrences
# Top 50% most frequent distinct titles cover 73.97% of title occurrences

# %%
total_titles
# Out:
# 597372

# %% [markdown]
# # Display some of the job title data from each bucket.

# %%
# Import necessary libraries
import pandas as pd
import os
from data_loader import read_and_flatten_data, preprocess_text
import random

# Helper function to sample 1000 titles from a series
def sample_titles(title_series, n=1000):
    if len(title_series) >= n:
        return title_series.sample(n)
    else:
        return title_series

# Define the buckets
title_counts = df['title'].value_counts()
unique_titles = title_counts[title_counts == 1]
non_unique_titles = title_counts[title_counts > 1]
top_50_percent_titles = title_counts.head(int(len(title_counts) * 0.50))
top_20_percent_titles = title_counts.head(int(len(title_counts) * 0.20))
top_10_percent_titles = title_counts.head(int(len(title_counts) * 0.10))
top_5_percent_titles = title_counts.head(int(len(title_counts) * 0.05))
top_10k_titles = title_counts.head(10000)

# Print out the counts of distinct job titles in each bucket
print(f"Distinct job titles with frequency = 1: {unique_titles.count()}")
print(f"Distinct job titles with frequency > 1: {non_unique_titles.count()}")
print(f"Distinct job titles in top 50% most frequent: {top_50_percent_titles.count()}")
print(f"Distinct job titles in top 20% most frequent: {top_20_percent_titles.count()}")
print(f"Distinct job titles in top 10% most frequent: {top_10_percent_titles.count()}")
print(f"Distinct job titles in top 5% most frequent: {top_5_percent_titles.count()}")
print(f"Distinct job titles in top 10,000 most frequent: {top_10k_titles.count()}")

# Sample 1000 titles from each bucket
unique_sample = sample_titles(unique_titles, 1000)
non_unique_sample = sample_titles(non_unique_titles, 1000)
top_50_sample = sample_titles(top_50_percent_titles, 1000)
top_20_sample = sample_titles(top_20_percent_titles, 1000)
top_10_sample = sample_titles(top_10_percent_titles, 1000)
top_5_sample = sample_titles(top_5_percent_titles, 1000)
top_10k_sample = sample_titles(top_10k_titles, 1000)

# Combine samples into a single DataFrame
samples_df = pd.DataFrame({
    'unique_titles': unique_sample.index,
    'non_unique_titles': non_unique_sample.index,
    'top_50_percent_titles': top_50_sample.index,
    'top_20_percent_titles': top_20_sample.index,
    'top_10_percent_titles': top_10_sample.index,
    'top_5_percent_titles': top_5_sample.index,
    'top_10k_titles': top_10k_sample.index
})

# Set display options to show all rows in the DataFrame
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# Display the DataFrame
samples_df.head(100)  # Display the first 100 rows
# Out:
# Distinct job titles with frequency = 1: 273982
# Distinct job titles with frequency > 1: 37041
# Distinct job titles in top 50% most frequent: 155511
# Distinct job titles in top 20% most frequent: 62204
# Distinct job titles in top 10% most frequent: 31102
# Distinct job titles in top 5% most frequent: 15551
# Distinct job titles in top 10,000 most frequent: 10000
#                                         unique_titles  \
# 0           group investment strategist (unit trusts)
# 1       product specialist - high speed video cameras
# 2             research assistant  computer vision lab
# 3                                       ui  developer
# 4                    asst. sailing director/lifeguard
# 5   assistant director, global / americas internal...
# 6   worldwide optimisation - asia pacific program ...
# 7               co-founder & director, scs youth club
# 8                       supervisor sterile processing
# 9                    regional territory-sales manager
# 10                       hardware/software sales team
# 11                               milieu counselor iii
# 12               senior operations analyst (contract)
# 13                               senior engineer/lead
# 14                             assembly/test operator
# 15                           supply side sales intern
# 16                          senior litigation counsel
# 17  marketing manager, executive assistant to ceo,...
# 18                        senior cra & project leader
# 19  global customer success - customer success man...
# 20               purchasing executive / sales support
# 21                                erp systems manager
# 22     assitstant director, business systems analysis
# 23                         electronic warfare officer
# 24                       asst manager special project
# 25                       office assistant & purchaser
# 26  senior technical marketing engineer/business d...
# 27  director architecture & engineering - video en...
# 28                  government senior account manager
# 29             assistant vice president of operations
# 30  head of sales, mid-market brands at oracle dat...
# 31              workplace ethics and concerns manager
# 32         electrical and instrumentation engineering
# 33              manager  channel business development
# 34  senior manager  systems engineering - governme...
# 35                  cyberspace vulnerability assessor
# 36         imyb-- innovation management yellow belt™️
# 37                                 internal marketing
# 38                     assistant operations executive
# 39                   digital marketing manager (lead)
# 40                                   resource analyst
# 41                                             deacon
# 42         assistant professor - strategic management
# 43                                   print instructor
# 44  supply chain supervisor | supply chain plannin...
# 45                             secretary & translater
# 46               solutions architect - major accounts
# 47         senior director, health insurance practice
# 48                   private client - account manager
# 49                senior technical manager /architect
# 50                                cavalry scout (19d)
# 51                                  splunk es analyst
# 52                             hsse advisor (project)
# 53                    quality systems  project leader
# 54  collective responsibility of four pillars of a...
# 55                          group development manager
# 56                                web updates manager
# 57                                 dental  consultant
# 58  начальник отдела подготовки производства, нача...
# 59                senior software engineer networking
# 60        risk & security engineer (sailpoint expert)
# 61    senior manager, wafer fab equipment engineering
# 62           assistant manager - transaction services
# 63                  web ui engineer | product analyst
# 64                         gdd aml compliance analyst
# 65            category manager rf & fiber connections
# 66        senior director  strategic planning and m&a
# 67                             crm & marketing intern
# 68                   front end software engineer  web
# 69                     assistant professor / lecturer
# 70                  senior associate storage engineer
# 71  program manager, professional services/ busine...
# 72   erp technology lead (order management & pricing)
# 73  social media manager - california newspapers p...
# 74  director business intelligence - yahoo news & ...
# 75  chief technology officer & vice president  car...
# 76                                 day trading intern
# 77                                  sr qa / team lead
# 78         it business analyst and software developer
# 79                         customer service cum admin
# 80           territory account manager  channel sales
# 81               senior architect systems engineering
# 82                     security stack design engineer
# 83                                 vessels operations
# 84                                     chairman owner
# 85    national technical, channel & marketing manager
# 86        director  platform marketing for salesforce
# 87            senior project manager (design manager)
# 88                      tibco - professional services
# 89  teaching assistant  computer science and engin...
# 90                                 oim - base manager
# 91                             iot solutions engineer
# 92  it technology manager-global customer visit ce...
# 93                coordinator, cs training compliance
# 94        director  showcase crm portfolio management
# 95                 administrative assistant co access
# 96                                   farms apprentice
# 97                        corporate bond analyst m&ib
# 98                    technology dept. deputy manager
# 99  international business development manager-mat...
#
#                                     non_unique_titles  \
# 0                          cyber security engineer ii
# 1                          senior solution consultant
# 2                              treasury administrator
# 3                                   group it director
# 4                        global manufacturing it head
# 5                                                 fse
# 6                            data management engineer
# 7                        director of client relations
# 8                      quality and operations manager
# 9   lead corporate recruiter, human resource depar...
# 10                 senior technical support associate
# 11                          head of people operations
# 12                                       ops director
# 13                              enterprise consultant
# 14                                    corporate pilot
# 15                                  storyboard artist
# 16                      director (land & liveability)
# 17  senior partner, managing director, corporate a...
# 18                             associate metallurgist
# 19          director of infrastructure and operations
# 20                                        lead server
# 21                            client services officer
# 22                                regulatory engineer
# 23                                   corporate banker
# 24                                    student teacher
# 25                                  radio broadcaster
# 26                                    web development
# 27                                             sde ii
# 28                           global sales development
# 29       senior quality assurance automation engineer
# 30                        admin and finance executive
# 31                                                 ea
# 32                              oracle soa consultant
# 33          vice president (consumer & channel sales)
# 34                                 global data intern
# 35    general manager (investment & asset management)
# 36                              contract metallurgist
# 37                 training & development coordinator
# 38                       software engineer consultant
# 39                senior market development executive
# 40  client relationship manager, centurion & plati...
# 41                        software development manger
# 42                                   chief controller
# 43                                      stage manager
# 44     vice president, investments & asset management
# 45                     global assistant brand manager
# 46              executive team leader, team relations
# 47                        business development leader
# 48  data scientist, senior manager, recommender sy...
# 49                          global solution architect
# 50                          solution sales specialist
# 51                                industrial director
# 52                             senior product manager
# 53                  manager, operations & development
# 54                                 instructor/trainer
# 55                research and development specialist
# 56                                       duty manager
# 57                              devops tools engineer
# 58              financial planning & analysis manager
# 59                          senior it systems analyst
# 60                              principle qa engineer
# 61                            asst operations manager
# 62                           senior quantity surveyor
# 63       senior systems integration and test engineer
# 64                      senior benefits administrator
# 65       senior hse supervisor / equipment supervisor
# 66                                         head clerk
# 67                         senior marketing assistant
# 68                            country head, singapore
# 69                 occupational therapy fw ii student
# 70      marketing assistant / a&p and event executive
# 71                          director and share holder
# 72                            sr. corporate recruiter
# 73                                     director, fp&a
# 74                     senior sales account executive
# 75                   fundraising & development intern
# 76                            graduate civil engineer
# 77                                 bestselling author
# 78                          senior property executive
# 79                     undergraduate trainee engineer
# 80                                             md/ceo
# 81                            clerical specialist iii
# 82                                     global manager
# 83  senior manager regional direct & digital business
# 84                         guest relations specialist
# 85           district sales manager - south east asia
# 86                               senior mine engineer
# 87                                consultant engineer
# 88                                      test director
# 89  production planning control (ppc) and sourcing...
# 90                          general manager - finance
# 91                       manager quality - black belt
# 92                             hookup section manager
# 93                                 geology consultant
# 94                               communications co-op
# 95                       product management associate
# 96                       assistant hr & admin manager
# 97                                            greeter
# 98                intern - business legal consultancy
# 99                          employee benefits manager
#
#                                 top_50_percent_titles  \
# 0   technical team leader - customer success engin...
# 1                        researcher/call center agent
# 2                      director of balance laboratory
# 3    consultant/senior accountant, regulatory support
# 4                    managing director / psychologist
# 5                         managing director/gm  sales
# 6                        manager, mutual fund trading
# 7                        digital campaigns specialist
# 8                          account recruiting manager
# 9                                     trainee analyst
# 10                         orientation leader captain
# 11                         student internship program
# 12                          dat/oat course instructor
# 13                             ux/ui development lead
# 14                 finance division student assistant
# 15                            learning and od manager
# 16                   marketing communications & sales
# 17           regional sales director, south east asia
# 18              vice president - compliance assurance
# 19         intern, transaction tax & transfer pricing
# 20                                    ceo, sp digital
# 21                                    metro recruiter
# 22                    regional vice president (china)
# 23  executive director, apac leadership and talent...
# 24                       senior secretariat executive
# 25  director of product management for automated s...
# 26       managing director - alcoa inter-america inc.
# 27                 media relations graduate assistant
# 28                                linkedin influencer
# 29          business development manager - mid market
# 30                  senior business & personal banker
# 31                               it portfolio manager
# 32                           commercial sales manager
# 33                        cio standard chartered bank
# 34                       medical laboratory scientist
# 35                 sr. information security architect
# 36                         compliance/ agency support
# 37                         head strategic development
# 38                         mutual fund tax accountant
# 39                                guest correspondent
# 40  sr. business systems support analyst (applicat...
# 41                intern, computer science department
# 42                                        center head
# 43   ui technical lead, application software engineer
# 44  manager of clinical education and professional...
# 45  orthopedic technician, surgery scheduler, unit...
# 46                               campus news reporter
# 47                           stress analysis engineer
# 48                       sales & application engineer
# 49              senior equipment engineer - metrology
# 50                           storage and backup admin
# 51                    senior crm manager - salesforce
# 52                       manager - network scheduling
# 53                                      seo team lead
# 54  it project coordinator contracted with bank of...
# 55          chief marine engineer (heracles) oil/chem
# 56  institutional marketing and research for asia ...
# 57                              asst. quality manager
# 58                         disability program manager
# 59                    auto body sheet metal fabicator
# 60  head of corporate & regulatory affairs, singapore
# 61    interim health services manager/occupational rn
# 62                            consultant psychologist
# 63                 sr officer - chartering (dry bulk)
# 64                  financial accountant / consultant
# 65                         partner at rhtlaw asia llp
# 66  director (it and business systems integration)...
# 67                            marketing | india | sea
# 68                               director of banquets
# 69                             senior risk consultant
# 70                         geologist, exploration r&d
# 71   employee relations & employee engagement manager
# 72                    customer service operations- qa
# 73                online content marketing specialist
# 74  chief information security officer & assistanc...
# 75                  vice president product management
# 76  senior director, medicaid strategies and programs
# 77                                    manager of hris
# 78               sr. officer corporate communications
# 79                            chief software engineer
# 80             td module & integration yield engineer
# 81  temporary staff, permanent residents service c...
# 82                        subsea proposals specialist
# 83  specialist recruiter, supply chain/logistics/p...
# 84          umts system & integrated testing engineer
# 85      senior vice president, regional bancassurance
# 86  project coordinator, healthcare infrastructure...
# 87                account manager - national accounts
# 88                                options coordinator
# 89                      vice president human resource
# 90                           web and graphic designer
# 91                                                hsa
# 92            senior software engineer, dev team lead
# 93               assistant director (client services)
# 94                           commissioning electrical
# 95              partner and senior network consultant
# 96        senior corporate counsel  iot (products) bu
# 97                                 senior paraplanner
# 98                            commercial sales, asean
# 99                      it consultant / hr consultant
#
#                                 top_20_percent_titles  \
# 0                           associate tech specialist
# 1                      director of corporate security
# 2                                     president / ceo
# 3                      student research assistant iii
# 4                  president & regional vp - americas
# 5                                      kitchen helper
# 6                        group chief security officer
# 7                 vice president of residential sales
# 8                               project site engineer
# 9                 corporate advisory senior associate
# 10               assistant manager talent acquisition
# 11              founder and chair, board of directors
# 12        group financial planning & analysis manager
# 13                                      pr consultant
# 14                        manager, general accounting
# 15                  managing director human resources
# 16                                 millwright foreman
# 17                         customer experience intern
# 18             practice team lead - business analysis
# 19                                       psychiatrist
# 20                           head of customer success
# 21                           senior district director
# 22                          lead sales representative
# 23                     senior group division director
# 24                                         ti suporte
# 25                            remote support engineer
# 26  control desk supervisor / administrative assis...
# 27                                      hr internship
# 28                         enterprise product manager
# 29      assistant executive, global business division
# 30                            head of events, opszest
# 31            advanced care partner, ob surgical tech
# 32  applications sales manager and solution specia...
# 33                            wellness program intern
# 34      commerical account development representative
# 35                             division sales manager
# 36                      corporate procurement manager
# 37  brand and marketing strategy for technology, t...
# 38      vice president - sales (asia & latin america)
# 39                          corporate market director
# 40                  assistant manager sales marketing
# 41                                  reporting manager
# 42                  employee relations representative
# 43                                     customs broker
# 44               data governor & manager, master data
# 45                                      brand advisor
# 46                                            asst gm
# 47            business office order specialist/typist
# 48                                       deal manager
# 49                                    chinese teacher
# 50       senior brand manager, ambient dairy business
# 51                            senior training manager
# 52                vice president, treasury department
# 53                          investor relations intern
# 54            internet and print marketing consultant
# 55                            f&b operational trainee
# 56  project engineer, assembly, test and launch op...
# 57                                      guest teacher
# 58                  director video product management
# 59                                     marketing head
# 60             manager, financial planning & analysis
# 61            sr. field engineer(plant and machinery)
# 62                            pr & marketing director
# 63                    global wealth management intern
# 64                                 finance department
# 65      sr. oracle application database administrator
# 66                                    sales manager 2
# 67                          director of human capital
# 68                               addictions counselor
# 69                               solutions specialist
# 70                  account manager, enterprise sales
# 71               working capital and treasury manager
# 72                          manager employee services
# 73  head of talent (acquisition, performance & eng...
# 74                 non executive independent director
# 75                                   noc technician 2
# 76                                         head chair
# 77                                fleet administrator
# 78                                  director - mining
# 79                          business office assistant
# 80  senior bigdata engineer | analytics & informat...
# 81                      director, consumer excellence
# 82                       manager - corporate strategy
# 83                        hardware / network engineer
# 84                  service / installation technician
# 85                     business it support technician
# 86                infrastructure engineer, specialist
# 87                           software release manager
# 88  eo emp (entrepreneurial masters program) co-chair
# 89                            business system advisor
# 90                      litigation support specialist
# 91                             account assistant (ar)
# 92                        digital media planner/buyer
# 93                       preschool teaching assistant
# 94                 professor of communication studies
# 95                                             tester
# 96                     brewery quality control intern
# 97                  consultant, professional services
# 98  country manager, new equipment sales & operations
# 99                                   paraprofessional
#
#                                 top_10_percent_titles  \
# 0                   co founder | project & it manager
# 1                             uk financial controller
# 2                        program manager (contractor)
# 3                                   member tech staff
# 4                                        bss engineer
# 5           assistant manager group finance reporting
# 6                  retail operations training manager
# 7                   mechanical completion coordinator
# 8                     senior cloud solution architect
# 9                senior head, higher education policy
# 10                                  owner / developer
# 11                                valuation executive
# 12                                assistant professor
# 13                           vice president - partner
# 14                            customer care executive
# 15                            java software developer
# 16                market research analyst (freelance)
# 17                         corporate secretarial exec
# 18                                     junior analyst
# 19                                hr & office manager
# 20                 application development specialist
# 21                            sales support executive
# 22                                  tool room manager
# 23                     network & system administrator
# 24                        senior system test engineer
# 25                                   leasing director
# 26                registered client service associate
# 27  senior vice president & chief information officer
# 28                       assistant laboratory manager
# 29                                  design researcher
# 30                                          registrar
# 31                           associate, risk advisory
# 32                  qc inspector and ndt co-ordinator
# 33                          commercial banking intern
# 34            senior manager, higher education policy
# 35                          system specialist storage
# 36              systems integration and test engineer
# 37                 non-executive independent director
# 38                                  founder/developer
# 39                        manager - vendor operations
# 40                                  retail consultant
# 41                      managing director (singapore)
# 42                 associate director, head of retail
# 43                               office specialist ii
# 44                        emergency department scribe
# 45                          lead reliability engineer
# 46                     credit and collections analyst
# 47                  sr. specialist technical training
# 48                       credit documentation manager
# 49                                community developer
# 50                    associate deputy group director
# 51           epic manager of revenue cycle operations
# 52                 vice president product development
# 53                          head, risk and governance
# 54                               logistics operations
# 55  commercial strategy & network development lead...
# 56                         general manager commercial
# 57                         delivery project executive
# 58                                     service banker
# 59                                         classified
# 60                                        mis manager
# 61  senior manager, corporate finance & investor r...
# 62                          marketing sales executive
# 63                                    computer repair
# 64                                      snr executive
# 65                                 pre-press operator
# 66       senior software quality assurance consultant
# 67                                 architect/designer
# 68                                  lead a&p mechanic
# 69                                     policy officer
# 70                                 digital innovation
# 71                     technical solutions consultant
# 72                        contract software developer
# 73                             data migration analyst
# 74                             major account director
# 75        pharmacy technology services senior manager
# 76             project manager(pub developed project)
# 77                               international intern
# 78                           chief everything officer
# 79                          temporary audit assistant
# 80                      senior premier field engineer
# 81                             assistant manager (it)
# 82                                      owner/partner
# 83                                   project designer
# 84                     software development team lead
# 85                               assistant it manager
# 86                                     flyer for hire
# 87                                        able seaman
# 88    senior team lead/product architect project iris
# 89                associate customer support engineer
# 90  rcm2 / rcm3 practitioner (certified from alado...
# 91                    associate test product engineer
# 92                                 commercial analyst
# 93                                asst centre manager
# 94             regional sales manager south east asia
# 95                       strategic engagement manager
# 96                                           motorman
# 97                                    planning intern
# 98                                staff correspondent
# 99                               data science student
#
#                                  top_5_percent_titles  \
# 0                          executive director, retail
# 1                                     studio director
# 2                              professional recruiter
# 3                                              broker
# 4                      sr. human resources generalist
# 5                            manager, risk management
# 6                                 per diem pharmacist
# 7                                           publisher
# 8                             senior managing partner
# 9                                 operation assistant
# 10                                    imagery analyst
# 11                          sales & operation manager
# 12                             data management intern
# 13                          equity derivatives trader
# 14                          product design contractor
# 15                               equipment technician
# 16                                   learning manager
# 17                                 writer (freelance)
# 18                            ceo & managing director
# 19                                internal controller
# 20                                 business developer
# 21                        assurance assistant manager
# 22                  international marketing executive
# 23                             sales support engineer
# 24                                        court clerk
# 25                           brand operations manager
# 26                        high commissioner singapore
# 27                                    temporary staff
# 28                                      brand advisor
# 29                   business intelligence specialist
# 30          senior marketing communications executive
# 31                       manager, business operations
# 32                            group company secretary
# 33                                            colonel
# 34                         senior structural designer
# 35                    senior consultant - engineering
# 36                               assistente comercial
# 37                                         qa/qc lead
# 38                    certified veterinary technician
# 39                           senior systems architect
# 40                          revenue assurance analyst
# 41                            chairman advisory board
# 42                   avp, loan administration manager
# 43                         quality operations manager
# 44                                  materials handler
# 45                       assistant operations officer
# 46                           senior warehouse manager
# 47                     manager information technology
# 48                                 chief officer sdpo
# 49                                         pre-loader
# 50                          mechanical superintendent
# 51                          sales integration manager
# 52                      software developer consultant
# 53                               senior data engineer
# 54                                         tool maker
# 55                          special education teacher
# 56  head of ara group risk management & internal a...
# 57                                   senior team lead
# 58         administrative assistant, customer service
# 59        trainee solicitor (relevant legal training)
# 60                        product engineering manager
# 61                                    product advisor
# 62                        senior production executive
# 63                                       crew manager
# 64                                    masters student
# 65                          patient service associate
# 66                                   station engineer
# 67                                 hr account manager
# 68               assistant manager, sales & marketing
# 69                                executive president
# 70                         head of regulatory affairs
# 71                                     group head, hr
# 72                          guest services supervisor
# 73                        senior contracts specialist
# 74                                        field sales
# 75                         project manager/consultant
# 76                                        tcs manager
# 77                             deputy manager finance
# 78                                             parent
# 79    senior vice president & chief financial officer
# 80                 regional sales & marketing manager
# 81                        senior integration engineer
# 82                                          ceo/owner
# 83                          tax manager, asia pacific
# 84                                     private banker
# 85                                     talent manager
# 86                            offshore crane operator
# 87                                asean legal counsel
# 88                                        design lead
# 89                                        mould maker
# 90                                    trust associate
# 91                               after sales engineer
# 92                 assistant manager, brand marketing
# 93                               certified nurse aide
# 94                   assistant manager, human capital
# 95                                 general management
# 96                                          assurance
# 97                 office manager/executive assistant
# 98                                   associate pastor
# 99                          executive, group treasury
#
#                              top_10k_titles
# 0                               scm manager
# 1                            community lead
# 2                  customer account manager
# 3                        director, projects
# 4                      chartering executive
# 5                            pr coordinator
# 6                                  buyer ii
# 7        insulation and cladding supervisor
# 8               assistant director of sales
# 9                               taxi driver
# 10              product development manager
# 11                           senior auditor
# 12           senior human resources analyst
# 13                          desktop support
# 14                          ambulance medic
# 15        senior manager strategic sourcing
# 16         senior customer service engineer
# 17                          strategic buyer
# 18                         process engineer
# 19                   transplant coordinator
# 20              accounts payable supervisor
# 21                        assistant auditor
# 22                 national sales recruiter
# 23                                team lead
# 24             application developer intern
# 25                              audit staff
# 26                          senior operator
# 27                       program management
# 28         vice president & general manager
# 29                principal product manager
# 30    workplace safety & health coordinator
# 31               client technology engineer
# 32            vice president internal audit
# 33            talent acquisition consultant
# 34                                       rn
# 35         equipment maintenance technician
# 36                 physical design engineer
# 37                                 minister
# 38                       purchase executive
# 39          application development manager
# 40                   independent consultant
# 41                          official member
# 42             chairman & managing director
# 43             oracle functional consultant
# 44                          owner/principal
# 45          regional human resource manager
# 46                            grocery buyer
# 47            principal mechanical engineer
# 48                  social media strategist
# 49                       consulting manager
# 50                 senior sales coordinator
# 51                     senior store manager
# 52                         sr hr generalist
# 53                             executive vp
# 54                 full stack web developer
# 55               assistant project engineer
# 56               oral maxillofacial surgeon
# 57  senior human resources business partner
# 58             physical therapist assistant
# 59                      engineering analyst
# 60                  master control operator
# 61                       financial director
# 62                     analytical scientist
# 63                                      asm
# 64                             soccer coach
# 65      senior technical marketing engineer
# 66                java full stack developer
# 67                        psychology intern
# 68                       professional actor
# 69             senior production supervisor
# 70            sales & marketing coordinator
# 71                      after sales manager
# 72                  senior accounts officer
# 73                            naval officer
# 74           business development executive
# 75               vice president, investment
# 76                          risk consultant
# 77                               math tutor
# 78                           master planner
# 79                          staff assistant
# 80                  staff firmware engineer
# 81                             web producer
# 82                     shift superintendent
# 83                         president, owner
# 84                        projects engineer
# 85                          audit assurance
# 86                   senior piping designer
# 87                       strategy associate
# 88        treasury management sales analyst
# 89                         hadoop developer
# 90                  product design engineer
# 91      marketing communications specialist
# 92           implementation project manager
# 93                 finance committee member
# 94               software quality assurance
# 95                  compensation specialist
# 96                       employment manager
# 97                    chief finance officer
# 98                    claims representative
# 99                 salesforce administrator
